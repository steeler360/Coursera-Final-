# %% [markdown]
# This is my final project, and this notebook will only be used for my final project. I hope I do everything right.

# %%
import pandas as pd
import numpy as np 
print(" Hello Capstone Project Course!")
# Out:
#  Hello Capstone Project Course!
